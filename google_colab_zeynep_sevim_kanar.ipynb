# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
sns.color_palette("colorblind")
sns.set_style("darkgrid")
sns.set_context("notebook")
#All libraries were imported, and color palette and grid were assigned

# %%
book_price=pd.read_excel('book_priceCleanData.xlsx')
book_price.head()
#The data were observed
# Out:
#    Unnamed: 0      Price Currency Unit Publisher     Type  No Of Page  Rating  \
# 0           0  84.350000            TL       Can  Science   62.000000    7.24
# 1           1  86.700000            TL     Doğan  Science   86.000000    7.03
# 2           2  74.400000            TL       Can  Science   67.000000    5.14
# 3           3  76.822476            TL     Doğan    Novel   78.781818   13.14
# 4           4  61.370000            TL       Can  Science   78.781818    2.77
#
#    Clicking Rate  Shipping Fee  Year Second Hand
# 0          5.534      16.00000  2017          No
# 1          5.283      18.00000  2019          No
# 2          5.294      20.88785  2017          No
# 3          6.094      20.88785  2022          No
# 4          4.547      23.00000  2016         Yes

# %%
plt.figure(figsize = (8,8))  
sns.boxplot(data=book_price, x="Rating", y="Type")
plt.title('Rating vs. Type',fontsize = 15, fontweight = "bold")
plt.xlabel('Rating')
plt.ylabel('Book Types')
plt.show() #Which type of books are liked more?Q1
#One categoric and one numeric variable visualized with customized box plot

# %%
plt.figure(figsize = (8,8))  
sns.relplot(data=book_price, y="Price", x="Clicking Rate", kind='scatter' )
plt.title('The Association Between Price and Clicking Rate',fontsize = 15, fontweight = "bold")
plt.xlabel('Clicking Rate')
plt.ylabel('Price')
plt.show() #Are the cheaper books clicked more?Q2
#Two numeric varible were visualized with customized scatterplot

# %%
plt.figure(figsize = (8,8)) 
sns.catplot(data=book_price, y="Price", x="Second Hand",
             kind='bar') 
plt.title('Price vs. Second Hand',fontsize = 15, fontweight = "bold")
plt.xlabel('Second Hand')
plt.ylabel('Price')
plt.show()    #Are second-hand books cheaper?Q3
#One categoric and one numeric variable were visualized with customized bar plot

# %%
plt.figure(figsize = (8,8)) 
sns.violinplot(data=book_price, x="Type", y="Price") 
plt.title('The Relationship between Type and Price',fontsize = 15, fontweight = "bold")
plt.xlabel('Type')
plt.ylabel('Price')
plt.show()  #How does the category of the books affect the price range and density of the prices?Q4
#One categoric and one numeric varible visualized with customized violin plot in order to observe the density also

# %%
plt.figure(figsize = (8,8))  
sns.violinplot(data=book_price, x="Publisher", y="Price")
plt.title('The Relationship Between Publisher and Price',fontsize = 15, fontweight = "bold")
plt.xlabel('Publisher')
plt.ylabel('Price')
plt.show()  #How does the publisher of the books affect the price range and the density of the prices?Q5
#One categoric and one numeric varible visualized with customized violin plot in order to observe the density also

# %%
plt.figure(figsize = (8,8)) 
sns.catplot(data=book_price, x="Clicking Rate", y="Type", kind='bar') 
plt.title('The Relationship between Type and Clicking Rate',fontsize = 15)
plt.ylabel('Type')
plt.show() #Which type of books are looked at more by consumers?Q6
#One categoric and one numeric varible were visualized with customized bar plot

# %%
sns.lineplot(x='Year' , y='Clicking Rate' , data=book_price, ci=None) 
plt.title('Clicking Rate Over the Years',fontsize = 15, fontweight = "bold")
#How does the clicking rate of the website change over the years?Q7
#Year varible was visualized with customized time series graph
# Out:
# Text(0.5, 1.0, 'Clicking Rate Over the Years')

# %%
plt.figure(figsize = (8,8)) 
sns.relplot(data=book_price, x="No Of Page", y="Shipping Fee", kind='scatter')
plt.title('Relationship Between Number Of Pages and Shipping Fee',fontsize = 15, fontweight = "bold")
plt.xlabel('No Of Page')
plt.ylabel('Shipping Fee')
plt.show() #Does the heavier books costs more for shipping?Q8
#Two numeric variables were visualized with customized scatter plot
